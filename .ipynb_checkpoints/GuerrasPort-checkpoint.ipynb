# %% [markdown]
# # ISCA - Trabalho 2

# %% [markdown]
# ## Guerras Portuguesas

# %%
# For loading images in the ipython from disk:
from IPython.display import Image

# %% [markdown]
# ### Contexto:

# %% [markdown]
# Este notebook iphyton foi criado no âmbito do trabalho 2 da Unidade Curricular de "Introdução ao Software de Código Aberto [MSCA]" com recurso aos dados disponibilizados pelo professor Carlos Costa no repositório GIT https://github.com/masterfloss/guerras_secXVII.git.
#
# O "dataset" de exemplo a observar não é de grande expressão devido ao reduzido numero de dados disponibilizado, ainda assim, serve sem duvida como intrudução à linguagem de programação Phyton e ao conceito de "machine Learning".
# <br><br><br>

# %%
Image(filename='slides/machinelearning.png')

# %% [markdown]
# <br>
# ### Poupando nas palavras... vamos então ao que interessa:

# %% [markdown]
# # Guerras Portuguesas

# %%
Image(filename='slides/guerraspt.png')

# %% [markdown]
# <br>
# ## Passo 1 - Importação, observação e manipulação de dados.
# <br>

# %%
#%pylab inline
import pylab as pl
import numpy as np
# For using pandas:
import pandas as pd
import statsmodels.api as sm
# For creating charts: 
from matplotlib import pyplot as plt

# for having the graphs show up in the notebook, instead of as a pop up: 
% matplotlib inline

# %% [markdown]
# ### Importação de dados:

# %%
guerraspt = pd.read_csv('dados.csv');

# %% [markdown]
# #### Vejamos então os dados importados.

# %%
guerraspt
# Out:
#               batalha   ano  portugueses  holandeses  ingleses  racio  \
# 0              Bantam  1601            6           3         0  2.000
# 1      Malacca Strait  1606           14          11         0  1.273
# 2       Ilha das Naus  1606            6           9         0  0.667
# 3          Pulo Butum  1606            7           9         0  0.778
# 4              Surrat  1615            6           0         4  1.500
# 5       Ilha das Naus  1615            3           5         0  0.600
# 6                Jask  1620            4           0         4  1.000
# 7              Hormuz  1622            6           0         5  1.200
# 8    Mogincoal Shoals  1622            4           4         2  0.667
# 9              Hormuz  1625            8           4         4  1.000
# 10                Goa  1636            6           4         0  1.500
# 11                Goa  1637            6           7         0  0.857
# ...

# %%
port = guerraspt['portugueses']
hol = guerraspt['holandeses'] 
ing = guerraspt['ingleses']
esp = guerraspt['espanhois']
vit = guerraspt['vitoria']

# %%
# reshape the data from a pandas Series to columns 
# the dependent variable
y = np.matrix(vit).transpose()
# the independent variables shaped as columns
x1 = np.matrix(port).transpose()
x2 = np.matrix(hol).transpose()
x3 = np.matrix(ing).transpose()
x4 = np.matrix(esp).transpose()

# %%
# put the two columns together to create an input matrix 
# if we had n independent variables we would have n columns here
x = np.column_stack([x1,x2,x3,x4])

# create a linear model and fit it to the data
X = sm.add_constant(x)
model = sm.OLS(y,X)
f = model.fit()

# %%
print('coeficients: ',f.params[0:4])
print('Intercept: ',f.params[4])
print('P-Values: ',f.pvalues)
print('R-Squared: ',f.rsquared)
# Out:
# coeficients:  [-0.05752095  0.02654692 -0.01460529 -0.08293093]
# Intercept:  -0.270810995312
# P-Values:  [ 0.75577071  0.05114901  0.04703065  0.01525448  0.38245304]
# R-Squared:  0.282072371217

# %% [markdown]
# # Outro dados...

# %%
guerraspt.drop('batalha', inplace=True, axis=1)

# %%
guerraspt.head()
# Out:
#     ano  portugueses  holandeses  ingleses  racio  espanhois  vitoria
# 0  1601            6           3         0  2.000          0        0
# 1  1606           14          11         0  1.273          0        0
# 2  1606            6           9         0  0.667          0       -1
# 3  1606            7           9         0  0.778          0        1
# 4  1615            6           0         4  1.500          0        0

# %%
print ("0  = Empates")
print ("-1 = Derrotas Portuguesas")
print ("1  = Vitorias Portuguesas")
guerraspt.vitoria.value_counts()
# Out:
# 0  = Empates
# -1 = Derrotas Portuguesas
# 1  = Vitorias Portuguesas
#  0    13
# -1    10
#  1     5
# Name: vitoria, dtype: int64

# %%
guerraspt.hist(column='portugueses', by='vitoria')
print ("Gráficos correspondentes ao numero de Portugueses de envolvidos em cada uma das batalhas por resultado.")
# Out:
# Gráficos correspondentes ao numero de Portugueses de envolvidos em cada uma das batalhas por resultado.
